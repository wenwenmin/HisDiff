# %% [markdown]
# kernel: https://github.com/mahmoodlab/HEST

# %%
from huggingface_hub import login

login(token="") # token=Your_HuggingFace_Token
# load metadata
import pandas as pd
meta_df = pd.read_csv("hf://datasets/MahmoodLab/hest/HEST_v1_1_0.csv")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to C:\Users\Administrator\.cache\huggingface\token
# Login successful

# %% [markdown]
# # Dataset - Human HER2ST

# %%
import datasets
import os

data_path = "./hest1k_datasets/her2st"
os.makedirs(data_path)

ids_to_query = meta_df.loc[meta_df["dataset_title"].str.startswith("Spatial deconvolution of"), "id"].tolist()
list_patterns = [f"*{id}[_.]**" for id in ids_to_query]
dataset = datasets.load_dataset(
    'MahmoodLab/hest', 
    cache_dir=data_path,
    patterns=list_patterns
)
# Test slide in the paper: SPA148 (B1)

# %% [markdown]
# # Dataset - cSCC

# %%
import datasets
import os

data_path = "./hest1k_datasets/cSCC"
os.makedirs(data_path)

ids_to_query = ["NCBI"+str(i) for i in range(759, 771)] 
list_patterns = [f"*{id}[_.]**" for id in ids_to_query]
dataset = datasets.load_dataset(
    'MahmoodLab/hest', 
    cache_dir=data_path,
    patterns=list_patterns
)
# Test slide in the paper: NCBI759

# %% [markdown]
# # Dataset - Human Prostate Cancer (PRAD)

# %%
import datasets
import os

data_path = "./hest1k_datasets/PRAD"
os.makedirs(data_path)

ids_to_query = ["MEND"+str(i) for i in range(139, 163)] # ID: MEND139~MEND162
list_patterns = [f"*{id}[_.]**" for id in ids_to_query]
dataset = datasets.load_dataset(
    'MahmoodLab/hest', 
    cache_dir=data_path,
    patterns=list_patterns
)
# Test slide in the paper: MEND145

# %% [markdown]
# # Dataset - DLPFC

# %%
import datasets
import os

data_path = "./hest1k_datasets/DLPFC"
os.makedirs(data_path)

ids_to_query = ["MISC"+str(i) for i in range(1, 13)] # ID: MEND139~MEND162
list_patterns = [f"*{id}[_.]**" for id in ids_to_query]
dataset = datasets.load_dataset(
    'MahmoodLab/hest', 
    cache_dir=data_path,
    patterns=list_patterns
)
# Test slide in the paper: MISC2
